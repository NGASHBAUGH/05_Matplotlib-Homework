# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
both = pd.merge(mouse_metadata,study_results,on = "Mouse ID",how = "outer")

# Display the data table for preview
both
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
both['Mouse ID'].count()
# Out:
# 1893

# %%
mcount = len(both['Mouse ID'].unique())
mcount
# Checking the number of mice.
# Out:
# 249

# %%
duplicated_mouse_id = both.loc[both.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()
duplicated_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#Use Dataframe.duplicated. Do a loc inside the duplicate
test = both.copy()
# dupbool = test.loc[both.duplicated(subset = ['Mouse ID','Timepoint'], keep= 'first')== True]


# print(len(dupbool))
# dupbool


#I tried running through it twice to see if the first time only grabbed one Mouse ID
delboth = test.drop_duplicates(subset = ['Mouse ID','Timepoint'], keep= 'first')
print(len(delboth))
delboth = delboth.drop_duplicates(subset = ['Mouse ID','Timepoint'], keep= 'first')
print(len(delboth))
delboth
# Out:
# 1888
# 1888
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1888 rows x 8 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID. 
alldup = both.loc[both.duplicated(subset = ['Mouse ID','Timepoint'], keep= False)== True]
print(len(alldup))
alldup
# Out:
# 10
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clboth  = both.drop_duplicates(subset = ['Mouse ID','Timepoint'], keep= 'first')
clboth
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1888 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clcount = len(clboth['Mouse ID'].unique())
clcount
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen


mousesummary = pd.DataFrame({"Mean" :clboth['Tumor Volume (mm3)'].mean(),
                             'Median' : clboth['Tumor Volume (mm3)'].median(),
                             "Mode" : clboth['Tumor Volume (mm3)'].mode(),
                             "Variance": clboth['Tumor Volume (mm3)'].var(),
                             "Std Deviation":clboth['Tumor Volume (mm3)'].std(),
                             "SEM":clboth['Tumor Volume (mm3)'].sem()
#                             "max":clboth['Tumor Volume (mm3)'].max(),
#                             "min":clboth['Tumor Volume (mm3)'].min()
                            })
mousesummary
# This method is the most straighforward, creating multiple series and putting them all together at the end.
# Out:
#         Mean     Median  Mode   Variance  Std Deviation       SEM
# 0  50.449276  48.951421  45.0  79.291277       8.904565  0.204933

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
clboth.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(['mean' ,'median','var','std','sem'])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

pdata = clboth.groupby(['Drug Regimen']).agg({'Mouse ID':'count'})
pbar = pdata.plot.bar(title = 'Number of Mice per Regimen',legend = False)
pbar.set_ylabel("Number of Mice")

plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
reg = clboth['Drug Regimen'].value_counts()

name = reg.keys()
num = list(reg)

plt.bar(name,num,color = 'b',align = 'center')
plt.title("Total Number of Mice per Treatment")
plt.xlabel('Drug Regument')
plt.ylabel('Number of Mice')
plt.xticks(name, rotation='vertical')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gdata = clboth.drop_duplicates('Mouse ID')
gdata = gdata.groupby(['Sex']).agg({'Mouse ID':'count'})

gdata = gdata.rename(columns ={'Mouse ID': ""})
gbar = gdata.plot.pie(subplots = True , colors = ['pink','blue'], title = 'Mice by Sex',autopct = "%.2f%%", startangle = 90, legend = False)


plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gen = clboth.drop_duplicates('Mouse ID')
gen = gen.groupby('Sex')['Mouse ID'].count()
label = gen.keys()
gnum = list(gen)


plt.pie(gnum,labels = label,autopct = '%1.1f%%',startangle = 90,
         colors = ['blue','pink'])

plt.title("Mice by Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens: 
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
FTdup = clboth.drop_duplicates(subset = ['Mouse ID'], keep= 'last')
FTdup1 = FTdup.loc[(FTdup['Drug Regimen'] == 'Capomulin') | (FTdup['Drug Regimen'] =='Ramicane')|
                     (FTdup['Drug Regimen'] == 'Infubinol')|(FTdup['Drug Regimen'] == 'Ceftamin')]
FTdup1['Drug Regimen']
# Out:
# 9        Ramicane
# 19      Capomulin
# 29      Capomulin
# 39      Capomulin
# 49       Ramicane
#           ...
# 1797     Ceftamin
# 1813    Infubinol
# 1845     Ceftamin
# 1855     Ceftamin
# 1872    Infubinol
# Name: Drug Regimen, Length: 100, dtype: object

# %%
# Put treatments into a list for for loop (and later for plot labels)

treat = list(FTdup1['Drug Regimen'].unique())

# Create empty list to fill with tumor vol data (for plotting)
tumdata = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 


for treatment in treat:
    treat_tumor = clboth.loc[clboth['Drug Regimen'] == treatment]
    quartiles = treat_tumor["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'For the Treatment of {treatment} the results are:')
    print(f"The lower quartile of Tumor Volume is: {lowerq}")
    print(f"The upper quartile of Tumor Volume is: {upperq}")
    print(f"The interquartile range of Tumor Volume is: {iqr}")
    print(f"The the median of Tumor Volume is: {quartiles[0.5]} ")
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    print('\n----------------------------------------\n')


         
    # Locate the rows which contain mice on each drug and get the tumor volumes
#locating final Tumor Volumes for each drug
cap = FTdup1.loc[(FTdup['Drug Regimen'] == 'Capomulin')]
ram = FTdup1.loc[(FTdup['Drug Regimen'] =='Ramicane')]
inf = FTdup1.loc[(FTdup['Drug Regimen'] == 'Infubinol')]
cef = FTdup1.loc[(FTdup['Drug Regimen'] == 'Ceftamin')]

#making the Tumor volumes into lists
ram = np.array(list(ram['Tumor Volume (mm3)'])).astype(np.float)
cap1 = np.array(list(cap['Tumor Volume (mm3)'])).astype(np.float)
inf = np.array(list(inf['Tumor Volume (mm3)'])).astype(np.float)
cef = np.array(list(cef['Tumor Volume (mm3)'])).astype(np.float)
#placing Lists into list
tlist = [ram,cap1,inf,cef]
 
    # add subset 
    

    #inside day 3 assignment 4
# Out:
# For the Treatment of Ramicane the results are:
# The lower quartile of Tumor Volume is: 36.67463458499999
# The upper quartile of Tumor Volume is: 45.0
# The interquartile range of Tumor Volume is: 8.325365415000007
# The the median of Tumor Volume is: 40.67323554
# Values below 24.18658646249998 could be outliers.
# Values above 57.48804812250001 could be outliers.
#
# ----------------------------------------
#
# For the Treatment of Capomulin the results are:
# The lower quartile of Tumor Volume is: 37.685932865
# The upper quartile of Tumor Volume is: 45.0
# The interquartile range of Tumor Volume is: 7.314067135000002
# The the median of Tumor Volume is: 41.557808879999996
# Values below 26.714832162499995 could be outliers.
# Values above 55.9711007025 could be outliers.
#
# ----------------------------------------
#
# For the Treatment of Infubinol the results are:
# The lower quartile of Tumor Volume is: 47.3123533
# The upper quartile of Tumor Volume is: 57.314443967500004
# The interquartile range of Tumor Volume is: 10.002090667500006
# The the median of Tumor Volume is: 51.82058438
# Values below 32.309217298749985 could be outliers.
# Values above 72.31757996875001 could be outliers.
#
# ----------------------------------------
#
# For the Treatment of Ceftamin the results are:
# The lower quartile of Tumor Volume is: 47.208427112500004
# The upper quartile of Tumor Volume is: 56.801437570000004
# The interquartile range of Tumor Volume is: 9.5930104575
# The the median of Tumor Volume is: 51.77615728000001
# Values below 32.818911426250004 could be outliers.
# Values above 71.19095325625 could be outliers.
#
# ----------------------------------------

# %%
#Four Treatments inside of 
tsize = FTdup1['Tumor Volume (mm3)']
bplot, ax1, = plt.subplots()



ax1.set_title('Tumor volume')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(FTdup1['Tumor Volume (mm3)'])




plt.show()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tsize = FTdup1['Tumor Volume (mm3)']
bplot, ax1, = plt.subplots()

figp = dict(markerfacecolor='r', marker='D')

ax1.set_title('Tumor volume')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(tlist, flierprops = figp)
plt.xticks(np.arange(len(treat))+1,treat)




plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

singlecap = clboth.loc[(clboth['Mouse ID'] == 't565')]

x_values = singlecap['Timepoint']
y_values = singlecap['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,y_values)
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
fullcap = clboth.loc[(clboth['Drug Regimen'] == 'Capomulin')]

Fx_values = fullcap['Weight (g)']
Fy_values = fullcap['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(Fx_values, Fy_values)
regress_values = Fx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(Fx_values,Fy_values)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
